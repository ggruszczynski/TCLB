# %%
import matplotlib.pyplot as plt
import os
#from utilites import read_data_from_timestep
import numpy as np
import pandas as pd
import csv
import re

# rho_ratio = '1'
# v = '001'
# Ux='001'

rho_ratio = '1'
v = '001'
U='0.01'
Uf=float(U)
Ustr=re.sub("\.", '', U)

folder_path_moving = os.path.join("~/DATA_FOR_PLOTS",
                           "moving_vs_resting_bubble","old",
                           "line_data_rho%s_v%s_oscillating_Ux%s" % (rho_ratio, v,Ustr))

folder_path_resting = os.path.join("~/DATA_FOR_PLOTS",
                           "moving_vs_resting_bubble","old",
                           "line_data_rho%s_v%s_oscillating_Ux%s" % (rho_ratio, v,Ustr))



# folder_path_moving = os.path.join("~/DATA_FOR_PLOTS",
#                            "moving_vs_resting_bubble",
#                            f"rho{rho_ratio}_v{v}_circular_U{Ustr}",
#                            "line_data")

# folder_path_resting = os.path.join("~/DATA_FOR_PLOTS",
#                            "moving_vs_resting_bubble",
#                            f"rho{rho_ratio}_v{v}_circular_U{Ustr}",
#                            "line_data")



frames_cm_resting = []
frames_mrt_resting = []
frames_cm_moving = []
frames_mrt_moving = []

# n = np.arange(127, 999, 128)
# n = np.arange(127, 256, 128)
n = np.arange(0, 999, 1)
i = np.arange(len(n))

u_diff = np.empty(len(n))
rho_diff = np.empty(len(n))

diam_x_cm_resting = np.empty(len(n))   # x coordinate of the center of mass of the bubble
diam_x_mrt_resting = np.empty(len(n))  # x coordinate of the center of mass of the bubble
diam_x_cm_moving = np.empty(len(n))    # x coordinate of the center of mass of the bubble
diam_x_mrt_moving = np.empty(len(n))   # x coordinate of the center of mass of the bubble

for i_, n_ in zip(i, n):
    frame_cm_resting = pd.read_csv(os.path.join(folder_path_resting, "cm_resting.%d.csv" % n_), delimiter="\t")
    frame_mrt_resting = pd.read_csv(os.path.join(folder_path_resting, "mrt_resting.%d.csv" % n_), delimiter="\t")
    frame_cm_moving = pd.read_csv(os.path.join(folder_path_moving, "cm_moving.%d.csv" % n_), delimiter="\t")
    frame_mrt_moving = pd.read_csv(os.path.join(folder_path_moving, "mrt_moving.%d.csv" % n_), delimiter="\t")

    def find_diameter(pf, threshold=0.5):
        scale_factor = 1001/256  
        # paraview dumps 1001 grid points from line plot, 
        # while simluation domain is 256 
        counter = 0          

        for pf_ in pf:
            if pf_ > threshold:
                counter += 1
                
        ans = counter/scale_factor
        return ans
    

    
    diam_x_cm_resting[i_] = find_diameter(frame_cm_resting['PhaseField'])
    diam_x_mrt_resting[i_] = find_diameter(frame_mrt_resting['PhaseField'])
    diam_x_cm_moving[i_] = find_diameter(frame_cm_moving['PhaseField'])
    diam_x_mrt_moving[i_] = find_diameter(frame_mrt_moving['PhaseField'])
    
    
#     def count_interpol(x,y, threshold=0.5): 
#         x_max = max(x)
#         n= len(x)
#         xvals = np.linspace(0, x_max, 10*n)
#         yinterp = np.interp(xvals, x, y)

#         scale_factor =x_max/n
#         counter = 1

#         for y_ in y:
#             if y_ > threshold:
#                 counter += 1

#         ans = counter*scale_factor
#         return ans
#     diam_x_cm_resting[i_] = count_interpol(frame_cm_resting['Points:0'], frame_cm_resting['PhaseField'])
#     diam_x_mrt_resting[i_] = count_interpol(frame_mrt_resting['Points:0'],frame_mrt_resting['PhaseField'])
#     diam_x_cm_moving[i_] = count_interpol(frame_cm_moving['Points:0'],frame_cm_moving['PhaseField'])
#     diam_x_mrt_moving[i_] = count_interpol(frame_mrt_moving['Points:0'],frame_mrt_moving['PhaseField'])

# %%
from scipy import interpolate

def make_plot(x1, y1, x2, y2, fig_name):
    plt.rcParams.update({'font.size': 30})
    plt.figure(figsize=(16, 8))
    # The basic slice syntax is i:j:k where i is the starting index, j is the stopping index, and k is the step
    
#     def smooth(x,y): 
#         x_ = x
#         y_ = y
#         x_ = x[0:len(x):5]  # wez co 5 
#         y_ = y[0:len(x):5]
#         tck,u = interpolate.splprep([x_,y_], s=0)
#         unew = np.arange(0, 1.01, 0.01)
#         out_x, out_y = interpolate.splev(unew, tck)
# #         return x_, y_
#         return out_x, out_y


#     x1, y1 = smooth(x1,y1)
#     x2, y2 = smooth(x2,y2)
    
    plt.plot(x1, y1, color="red", marker="o", markevery=10,  markersize=10, linestyle="-", label='current model')
    plt.plot(x2, y2, color="blue", marker="", linestyle="-", label='MRT')

    axes = plt.gca()
    # axes.set_xlim([xmin,xmax])
    # axes.set_ylim([-3E-7, 3E-7])
    plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
    plt.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
    plt.xlabel(r'x/L')
    plt.ylabel(r'$d_x$ [lu]')
    plt.grid(True)
    plt.legend()
    
    fig = plt.gcf()  # get current figure
    fig.savefig(fig_name )
    plt.show()
    plt.close(fig)    # close the figure

    
make_plot(x1=i*1E3, y1=diam_x_cm_resting,
          x2=i*1E3, y2=diam_x_mrt_resting,
          fig_name=f'bubble_diam_rho{rho_ratio}_v{v}_U{Ustr}_resting_frame.png',
         )   

make_plot(x1=i*1E3, y1=diam_x_cm_moving,
          x2=i*1E3, y2=diam_x_mrt_moving,
          fig_name=f'bubble_diam_rho{rho_ratio}_v{v}_U{Ustr}_moving_frame.png',
         )

# %%
def smooth(x):
    return x[0:len(x):2]
    
sdiam_x_cm_resting=smooth(diam_x_cm_resting)
sdiam_x_mrt_resting=smooth(diam_x_mrt_resting)
sdiam_x_cm_moving=smooth(diam_x_cm_moving)
sdiam_x_mrt_moving=smooth(diam_x_mrt_moving)
si=smooth(i)

# tck,u = interpolate.splprep([x,y], s=0)
# unew = np.arange(0, 1.01, 0.01)
# (out_x, out_y) = interpolate.splev(unew, tck)

# make plot
plt.figure(1)
plt.figure(figsize=(18, 14))
plt.rcParams.update({'font.size': 22})

# frame_n = 1
# plt.plot(frames_cm_moving[frame_n]['arc_length'], frames_cm_moving[frame_n]['PhaseField'], color="green", marker="", linestyle="-.",  label='cm_test')
# plt.plot(frames_mrt_moving[frame_n]['arc_length'], frames_mrt_moving[frame_n]['PhaseField'], color="red", marker="", linestyle="-", label='mrt_test')

plt.subplot(211)
plt.title('Resting frame')


plt.plot(si*1E3, sdiam_x_cm_resting, color="red", marker="", linestyle="-.", label='current model')
plt.plot(si*1E3, sdiam_x_mrt_resting, color="blue", marker="", linestyle="--", label='MRT')


# plt.plot(i*1E3, diam_x_cm_moving, color="yellow", marker="", linestyle="-.", label='current model')
# plt.plot(i*1E3, diam_x_mrt_moving, color="green", marker="", linestyle="--", label='MRT')
axes = plt.gca()
# axes.set_xlim([xmin,xmax])
axes.set_ylim([55, 105])
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
plt.ylabel(r'$d_x$ [lu]')
# plt.xlabel(r'iterations')
plt.grid(True)
plt.legend()

plt.subplot(212)
plt.title(r'Moving frame')
plt.plot(si*1E3, sdiam_x_cm_moving, color="red", marker="", linestyle="-.", label='current model')
plt.plot(si*1E3, sdiam_x_mrt_moving, color="blue", marker="", linestyle="--", label='MRT')

# plt.plot(line_size, theoretical, color="black", marker="x", linestyle="", label='theoretical')
axes = plt.gca()
# axes.set_xlim([xmin,xmax])
axes.set_ylim([55, 105])
plt.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
plt.ylabel(r'$d_x$ [lu]')
plt.xlabel(r'iterations')
plt.grid(True)
plt.legend()

# plt.text(0.0, 0.0, r'cm_bubble diam = %.2f' % diam_x_cm_moving[frame_n])

fig = plt.gcf()  # get current figure
plt.tight_layout()
# fig.savefig('bubble_diam_rho%s_v%s_Ma%s.png' % (rho_ratio, v, Ma))
fig.savefig('bubble_diam_rho%s_v%s_Ux%s.png' % (rho_ratio, v, Ustr))
# plt.subplots_adjust(top=1.55)
plt.show()
#plt.close(fig)    # close the figure

# %%
from scipy import interpolate

x = np.linspace(0, 2*np.pi, 10)
y = np.sin(x)
xvals = np.linspace(0, 2*np.pi, 50)
yinterp = np.interp(xvals, x, y)


def count(x,y, threshold=0.0):
    scale_factor = max(x)/len(x)
    counter = 1
    
    for y_ in y:
        if y_ > threshold:
            counter += 1
                
    ans = counter*scale_factor
    return ans


print(count(x,y))
print(count(xvals,yinterp))


import matplotlib.pyplot as plt
plt.figure(figsize=(18, 14))
plt.plot(x, y, 'o')
plt.grid(True)
plt.plot(xvals, yinterp, '-x')

x2 = interpolate.spline(t, x, nt)
y2 = interpolate.spline(t, y, nt)
plt.plot(x2, y2, label='dist_spline', marker="<")

tck,u = interpolate.splprep([x,y], s=0)
unew = np.arange(0, 1.01, 0.01)
(out_x, out_y) = interpolate.splev(unew, tck)

plt.plot(out_x, out_y, color='red', marker="o")



plt.show()
# Out:
# 3.141592653589793
# 3.1415926535897936
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
