# %%
import numpy as np
uf = 0.2886751346*1000  # Ma=0.5 lu/1000ts - 1 frame =1000ts
#uf = 0.0577350269*1000 # Ma=0.1 lu/1000ts - 1 frame =1000ts

x = [256*i for i in range(100)]

obrot = 256
lista = []

for i in range(len(x)):
    rest = x[i] % uf
    ile_kratek = x[i] / uf
#     print("i=%d \t ile_kratek=%f" %(i, ile_kratek))
    if ile_kratek % 1 < 0.05:
        lista.append(i)
        print("i=%d \t ile_kratek=%f" %(i, ile_kratek))

n = np.arange(46, 999, 47)  
print(n)
# Out:
# i=0 	 ile_kratek=0.000000
# i=35 	 ile_kratek=31.038350
# i=44 	 ile_kratek=39.019641
# i=53 	 ile_kratek=47.000931
# i=88 	 ile_kratek=78.039281
# i=97 	 ile_kratek=86.020571
# [ 46  93 140 187 234 281 328 375 422 469 516 563 610 657 704 751 798 845
#  892 939 986]

# %%
print(256/(0.2886751346*1000*140))
# Out:
# 0.006334357238995217

# %%
# uf = 0.2886751346*1000  # Ma=0.5 lu/1000ts - 1 frame =1000ts
uf = 0.0577350269*1000 # Ma=0.1 lu/1000ts - 1 frame =1000ts

x = [256*i for i in range(100)]

obrot = 256
lista = []

for i in range(len(x)):
    rest = x[i] % uf
    ile_kratek = x[i] / uf
#     print("i=%d \t ile_kratek=%f" %(i, ile_kratek))
    if ile_kratek % 1 < 0.05:
        lista.append(i)
        print("i=%d \t ile_kratek=%f" %(i, ile_kratek))

n = np.arange(234, 999, 235)  
print(n)
# Out:
# i=0 	 rest=0.000000
# i=7 	 rest=31.038350
# i=30 	 rest=133.021502
# i=53 	 rest=235.004654
# i=60 	 rest=266.043004
# i=83 	 rest=368.026156
# [234 469 704 939]
